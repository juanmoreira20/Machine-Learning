# %%
# !pip install gym[box2d] pyglet==1.3.2
# !pip install box2d pygame
# Out:
# Collecting box2d
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\jprmj\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-c8q04kf7\\box2d_b99f2c1ea32545b180fb4c220c8e3d37\\setup.py'"'"'; __file__='"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-c8q04kf7\\box2d_b99f2c1ea32545b180fb4c220c8e3d37\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\jprmj\AppData\Local\Temp\pip-wheel-wiiu6woe'
#        cwd: C:\Users\jprmj\AppData\Local\Temp\pip-install-c8q04kf7\box2d_b99f2c1ea32545b180fb4c220c8e3d37\
#   Complete output (28 lines):
#   Using setuptools (version 58.0.4).
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\Box2D
#   copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.9\Box2D
#   copying library\Box2D\__init__.py -> build\lib.win-amd64-3.9\Box2D
#   creating build\lib.win-amd64-3.9\Box2D\b2
#   copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.9\Box2D\b2
#   running build_ext
#   building 'Box2D._Box2D' extension
#   swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#   swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#   Box2D\Common\b2Math.h(67) : Warning 302: Identifier 'b2Vec2' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#   Box2D\Common\b2Math.h(158) : Warning 302: Identifier 'b2Vec3' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#   Box2D\Common\b2Math.h(197) : Warning 302: Identifier 'b2Mat22' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#   Box2D\Common\b2Math.h(271) : Warning 302: Identifier 'b2Mat33' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#   Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#   Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#   Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#   Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for box2d
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\jprmj\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-c8q04kf7\\box2d_b99f2c1ea32545b180fb4c220c8e3d37\\setup.py'"'"'; __file__='"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-c8q04kf7\\box2d_b99f2c1ea32545b180fb4c220c8e3d37\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\jprmj\AppData\Local\Temp\pip-record-na3l4vzf\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\jprmj\anaconda3\Include\box2d'
#          cwd: C:\Users\jprmj\AppData\Local\Temp\pip-install-c8q04kf7\box2d_b99f2c1ea32545b180fb4c220c8e3d37\
#     Complete output (28 lines):
#     Using setuptools (version 58.0.4).
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\Box2D
#     copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.9\Box2D
#     copying library\Box2D\__init__.py -> build\lib.win-amd64-3.9\Box2D
#     creating build\lib.win-amd64-3.9\Box2D\b2
#     copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.9\Box2D\b2
#     running build_ext
#     building 'Box2D._Box2D' extension
#     swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#     swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#     Box2D\Common\b2Math.h(67) : Warning 302: Identifier 'b2Vec2' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#     Box2D\Common\b2Math.h(158) : Warning 302: Identifier 'b2Vec3' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#     Box2D\Common\b2Math.h(197) : Warning 302: Identifier 'b2Mat22' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#     Box2D\Common\b2Math.h(271) : Warning 302: Identifier 'b2Mat33' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#     Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#     Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#     Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#     Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\jprmj\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-c8q04kf7\\box2d_b99f2c1ea32545b180fb4c220c8e3d37\\setup.py'"'"'; __file__='"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-c8q04kf7\\box2d_b99f2c1ea32545b180fb4c220c8e3d37\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\jprmj\AppData\Local\Temp\pip-record-na3l4vzf\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\jprmj\anaconda3\Include\box2d' Check the logs for full command output.
#   Using cached Box2D-2.3.2.tar.gz (427 kB)
# Requirement already satisfied: pygame in c:\users\jprmj\anaconda3\lib\site-packages (2.1.0)
# Building wheels for collected packages: box2d
#   Building wheel for box2d (setup.py): started
#   Building wheel for box2d (setup.py): finished with status 'error'
#   Running setup.py clean for box2d
# Failed to build box2d
# Installing collected packages: box2d
#     Running setup.py install for box2d: started
#     Running setup.py install for box2d: finished with status 'error'
# Collecting box2d
#   Using cached Box2D-2.3.2.tar.gz (427 kB)
# Collecting box2d-kengz
#   Downloading Box2D-kengz-2.3.3.tar.gz (425 kB)
# Building wheels for collected packages: box2d, box2d-kengz
#   Building wheel for box2d (setup.py): started
#   Building wheel for box2d (setup.py): finished with status 'error'
#   Running setup.py clean for box2d
#   Building wheel for box2d-kengz (setup.py): started
#   Building wheel for box2d-kengz (setup.py): finished with status 'error'
#   Running setup.py clean for box2d-kengz
# Failed to build box2d box2d-kengz
# Installing collected packages: box2d-kengz, box2d
#     Running setup.py install for box2d-kengz: started
#     Running setup.py install for box2d-kengz: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\jprmj\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-th9t7hc0\\box2d_aaa9a7c217aa4fbca593ffd826620dd3\\setup.py'"'"'; __file__='"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-th9t7hc0\\box2d_aaa9a7c217aa4fbca593ffd826620dd3\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\jprmj\AppData\Local\Temp\pip-wheel-ep58dlp0'
#        cwd: C:\Users\jprmj\AppData\Local\Temp\pip-install-th9t7hc0\box2d_aaa9a7c217aa4fbca593ffd826620dd3\
#   Complete output (28 lines):
#   Using setuptools (version 58.0.4).
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\Box2D
#   copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.9\Box2D
#   copying library\Box2D\__init__.py -> build\lib.win-amd64-3.9\Box2D
#   creating build\lib.win-amd64-3.9\Box2D\b2
#   copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.9\Box2D\b2
#   running build_ext
#   building 'Box2D._Box2D' extension
#   swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#   swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#   Box2D\Common\b2Math.h(67) : Warning 302: Identifier 'b2Vec2' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#   Box2D\Common\b2Math.h(158) : Warning 302: Identifier 'b2Vec3' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#   Box2D\Common\b2Math.h(197) : Warning 302: Identifier 'b2Mat22' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#   Box2D\Common\b2Math.h(271) : Warning 302: Identifier 'b2Mat33' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#   Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#   Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#   Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#   Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for box2d
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\jprmj\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-th9t7hc0\\box2d-kengz_3728ac90a8cf455a9774e0ff4b48d0c1\\setup.py'"'"'; __file__='"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-th9t7hc0\\box2d-kengz_3728ac90a8cf455a9774e0ff4b48d0c1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\jprmj\AppData\Local\Temp\pip-wheel-p9vnc7_z'
#        cwd: C:\Users\jprmj\AppData\Local\Temp\pip-install-th9t7hc0\box2d-kengz_3728ac90a8cf455a9774e0ff4b48d0c1\
#   Complete output (28 lines):
#   Using setuptools (version 58.0.4).
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\Box2D
#   copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.9\Box2D
#   copying library\Box2D\__init__.py -> build\lib.win-amd64-3.9\Box2D
#   creating build\lib.win-amd64-3.9\Box2D\b2
#   copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.9\Box2D\b2
#   running build_ext
#   building 'Box2D._Box2D' extension
#   swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#   swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#   Box2D\Common\b2Math.h(67) : Warning 302: Identifier 'b2Vec2' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#   Box2D\Common\b2Math.h(158) : Warning 302: Identifier 'b2Vec3' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#   Box2D\Common\b2Math.h(197) : Warning 302: Identifier 'b2Mat22' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#   Box2D\Common\b2Math.h(271) : Warning 302: Identifier 'b2Mat33' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#   Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#   Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#   Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#   Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for box2d-kengz
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\jprmj\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-th9t7hc0\\box2d-kengz_3728ac90a8cf455a9774e0ff4b48d0c1\\setup.py'"'"'; __file__='"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-th9t7hc0\\box2d-kengz_3728ac90a8cf455a9774e0ff4b48d0c1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\jprmj\AppData\Local\Temp\pip-record-0i2l6tf0\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\jprmj\anaconda3\Include\box2d-kengz'
#          cwd: C:\Users\jprmj\AppData\Local\Temp\pip-install-th9t7hc0\box2d-kengz_3728ac90a8cf455a9774e0ff4b48d0c1\
#     Complete output (28 lines):
#     Using setuptools (version 58.0.4).
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\Box2D
#     copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.9\Box2D
#     copying library\Box2D\__init__.py -> build\lib.win-amd64-3.9\Box2D
#     creating build\lib.win-amd64-3.9\Box2D\b2
#     copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.9\Box2D\b2
#     running build_ext
#     building 'Box2D._Box2D' extension
#     swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#     swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#     Box2D\Common\b2Math.h(67) : Warning 302: Identifier 'b2Vec2' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#     Box2D\Common\b2Math.h(158) : Warning 302: Identifier 'b2Vec3' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#     Box2D\Common\b2Math.h(197) : Warning 302: Identifier 'b2Mat22' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#     Box2D\Common\b2Math.h(271) : Warning 302: Identifier 'b2Mat33' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#     Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#     Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#     Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#     Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\jprmj\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-th9t7hc0\\box2d-kengz_3728ac90a8cf455a9774e0ff4b48d0c1\\setup.py'"'"'; __file__='"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-th9t7hc0\\box2d-kengz_3728ac90a8cf455a9774e0ff4b48d0c1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\jprmj\AppData\Local\Temp\pip-record-0i2l6tf0\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\jprmj\anaconda3\Include\box2d-kengz' Check the logs for full command output.

# %%
import gym
from gym.envs import box2d 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
environment_name = "CarRacing-v0"
env = gym.make(environment_name)

# %%
log_path = os.path.join('Training', 'Logs')
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
model.learn(total_timesteps=40000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Track generation: 1167..1463 -> 296-tiles track
# Logging to Training\Logs\PPO_3
# Track generation: 1103..1389 -> 286-tiles track
# Track generation: 1174..1472 -> 298-tiles track
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -53.4    |
# | time/              |          |
# |    fps             | 100      |
# |    iterations      | 1        |
# |    time_elapsed    | 20       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Track generation: 1187..1488 -> 301-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.6       |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 2           |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006716378 |
# |    clip_fraction        | 0.0808      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.00807     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.228       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.995       |
# |    value_loss           | 0.637       |
# -----------------------------------------
# Track generation: 1094..1376 -> 282-tiles track
# Track generation: 1120..1404 -> 284-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.5       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 3           |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009955881 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.11        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.987       |
# |    value_loss           | 0.445       |
# -----------------------------------------
# Track generation: 1124..1409 -> 285-tiles track
# Track generation: 1124..1409 -> 285-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 4           |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010311053 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.185       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0758      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.984       |
# |    value_loss           | 0.531       |
# -----------------------------------------
# Track generation: 1224..1534 -> 310-tiles track
# Track generation: 1006..1262 -> 256-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48         |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 5           |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012746172 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.181       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0544      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.969       |
# |    value_loss           | 0.482       |
# -----------------------------------------
# Track generation: 1202..1507 -> 305-tiles track
# Track generation: 1361..1705 -> 344-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -46.1       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 6           |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.017356306 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.374       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0518      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0236     |
# |    std                  | 0.959       |
# |    value_loss           | 0.361       |
# -----------------------------------------
# Track generation: 1208..1514 -> 306-tiles track
# Track generation: 1367..1713 -> 346-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -46.8       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 7           |
# |    time_elapsed         | 441         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016823638 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.11       |
# |    explained_variance   | 0.385       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0184      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0235     |
# |    std                  | 0.948       |
# |    value_loss           | 0.33        |
# -----------------------------------------
# Track generation: 1215..1522 -> 307-tiles track
# Track generation: 1317..1654 -> 337-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -47.7       |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 8           |
# |    time_elapsed         | 515         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.020606644 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.08       |
# |    explained_variance   | 0.395       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00254    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0306     |
# |    std                  | 0.937       |
# |    value_loss           | 0.306       |
# -----------------------------------------
# Track generation: 1052..1325 -> 273-tiles track
# Track generation: 1061..1332 -> 271-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1216..1524 -> 308-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.6       |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 9           |
# |    time_elapsed         | 588         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.027542498 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.289       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0156     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0328     |
# |    std                  | 0.929       |
# |    value_loss           | 0.261       |
# -----------------------------------------
# Track generation: 1157..1450 -> 293-tiles track
# Track generation: 1393..1745 -> 352-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.1       |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 10          |
# |    time_elapsed         | 659         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.020703753 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.03       |
# |    explained_variance   | 0.187       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0391      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0249     |
# |    std                  | 0.924       |
# |    value_loss           | 0.24        |
# -----------------------------------------
# Track generation: 1031..1300 -> 269-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.9       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 11          |
# |    time_elapsed         | 732         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.034088127 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.0442      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0311     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0353     |
# |    std                  | 0.913       |
# |    value_loss           | 0.145       |
# -----------------------------------------
# Track generation: 1023..1283 -> 260-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -53.1       |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 12          |
# |    time_elapsed         | 790         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.027406093 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.443       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0332     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0289     |
# |    std                  | 0.898       |
# |    value_loss           | 0.138       |
# -----------------------------------------
# Track generation: 1102..1384 -> 282-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1210..1517 -> 307-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -53.5      |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 13         |
# |    time_elapsed         | 849        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.03548632 |
# |    clip_fraction        | 0.286      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.9       |
# |    explained_variance   | 0.45       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.000216  |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0387    |
# |    std                  | 0.882      |
# |    value_loss           | 0.259      |
# ----------------------------------------
# Track generation: 1176..1474 -> 298-tiles track
# Track generation: 1162..1457 -> 295-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -54         |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 14          |
# |    time_elapsed         | 907         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.043884814 |
# |    clip_fraction        | 0.328       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.062      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0364     |
# |    std                  | 0.871       |
# |    value_loss           | 0.146       |
# -----------------------------------------
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1021..1285 -> 264-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -54        |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 15         |
# |    time_elapsed         | 964        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.04800459 |
# |    clip_fraction        | 0.356      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.82      |
# |    explained_variance   | 0.853      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0019     |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0441    |
# |    std                  | 0.862      |
# |    value_loss           | 0.159      |
# ----------------------------------------
# Track generation: 994..1249 -> 255-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1145..1435 -> 290-tiles track
# Track generation: 1279..1603 -> 324-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -54.3       |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 16          |
# |    time_elapsed         | 1035        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.044402353 |
# |    clip_fraction        | 0.342       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.8        |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0583     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0404     |
# |    std                  | 0.857       |
# |    value_loss           | 0.153       |
# -----------------------------------------
# Track generation: 1164..1459 -> 295-tiles track
# Track generation: 1037..1307 -> 270-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -54.2      |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 17         |
# |    time_elapsed         | 1113       |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.04973509 |
# |    clip_fraction        | 0.345      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.77      |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0332    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0494    |
# |    std                  | 0.846      |
# |    value_loss           | 0.151      |
# ----------------------------------------
# Track generation: 1240..1554 -> 314-tiles track
# Track generation: 1223..1539 -> 316-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -53.7      |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 18         |
# |    time_elapsed         | 1184       |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.06014932 |
# |    clip_fraction        | 0.368      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.73      |
# |    explained_variance   | 0.853      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00858   |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0405    |
# |    std                  | 0.833      |
# |    value_loss           | 0.164      |
# ----------------------------------------
# Track generation: 1179..1478 -> 299-tiles track
# Track generation: 1057..1325 -> 268-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -53.6       |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 19          |
# |    time_elapsed         | 1252        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.057189878 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0279     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0471     |
# |    std                  | 0.828       |
# |    value_loss           | 0.167       |
# -----------------------------------------
# Track generation: 1108..1389 -> 281-tiles track
# Track generation: 1181..1480 -> 299-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -53        |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 20         |
# |    time_elapsed         | 1321       |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.06352712 |
# |    clip_fraction        | 0.425      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.68      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00926   |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0518    |
# |    std                  | 0.821      |
# |    value_loss           | 0.135      |
# ----------------------------------------

# %%
sevaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# c:\Users\jprmj\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Track generation: 1146..1437 -> 291-tiles track
# Track generation: 1144..1434 -> 290-tiles track
# Track generation: 1048..1314 -> 266-tiles track
# Track generation: 874..1103 -> 229-tiles track
# Track generation: 1034..1298 -> 264-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1041..1305 -> 264-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1185..1489 -> 304-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 960..1210 -> 250-tiles track
# Track generation: 1072..1353 -> 281-tiles track
# Track generation: 1104..1384 -> 280-tiles track
# Track generation: 1095..1373 -> 278-tiles track
# Track generation: 947..1195 -> 248-tiles track
# (-51.4108791552484, 31.281848722656186)

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()

# %%
env.close()
