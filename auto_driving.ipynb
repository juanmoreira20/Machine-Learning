# %%
# !pip install gym[box2d] pyglet==1.3.2
# !pip install box2d pygame
# Out:
# Collecting box2d
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\jprmj\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-c8q04kf7\\box2d_b99f2c1ea32545b180fb4c220c8e3d37\\setup.py'"'"'; __file__='"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-c8q04kf7\\box2d_b99f2c1ea32545b180fb4c220c8e3d37\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\jprmj\AppData\Local\Temp\pip-wheel-wiiu6woe'
#        cwd: C:\Users\jprmj\AppData\Local\Temp\pip-install-c8q04kf7\box2d_b99f2c1ea32545b180fb4c220c8e3d37\
#   Complete output (28 lines):
#   Using setuptools (version 58.0.4).
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\Box2D
#   copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.9\Box2D
#   copying library\Box2D\__init__.py -> build\lib.win-amd64-3.9\Box2D
#   creating build\lib.win-amd64-3.9\Box2D\b2
#   copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.9\Box2D\b2
#   running build_ext
#   building 'Box2D._Box2D' extension
#   swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#   swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#   Box2D\Common\b2Math.h(67) : Warning 302: Identifier 'b2Vec2' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#   Box2D\Common\b2Math.h(158) : Warning 302: Identifier 'b2Vec3' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#   Box2D\Common\b2Math.h(197) : Warning 302: Identifier 'b2Mat22' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#   Box2D\Common\b2Math.h(271) : Warning 302: Identifier 'b2Mat33' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#   Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#   Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#   Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#   Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for box2d
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\jprmj\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-c8q04kf7\\box2d_b99f2c1ea32545b180fb4c220c8e3d37\\setup.py'"'"'; __file__='"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-c8q04kf7\\box2d_b99f2c1ea32545b180fb4c220c8e3d37\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\jprmj\AppData\Local\Temp\pip-record-na3l4vzf\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\jprmj\anaconda3\Include\box2d'
#          cwd: C:\Users\jprmj\AppData\Local\Temp\pip-install-c8q04kf7\box2d_b99f2c1ea32545b180fb4c220c8e3d37\
#     Complete output (28 lines):
#     Using setuptools (version 58.0.4).
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\Box2D
#     copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.9\Box2D
#     copying library\Box2D\__init__.py -> build\lib.win-amd64-3.9\Box2D
#     creating build\lib.win-amd64-3.9\Box2D\b2
#     copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.9\Box2D\b2
#     running build_ext
#     building 'Box2D._Box2D' extension
#     swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#     swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#     Box2D\Common\b2Math.h(67) : Warning 302: Identifier 'b2Vec2' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#     Box2D\Common\b2Math.h(158) : Warning 302: Identifier 'b2Vec3' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#     Box2D\Common\b2Math.h(197) : Warning 302: Identifier 'b2Mat22' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#     Box2D\Common\b2Math.h(271) : Warning 302: Identifier 'b2Mat33' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#     Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#     Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#     Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#     Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\jprmj\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-c8q04kf7\\box2d_b99f2c1ea32545b180fb4c220c8e3d37\\setup.py'"'"'; __file__='"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-c8q04kf7\\box2d_b99f2c1ea32545b180fb4c220c8e3d37\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\jprmj\AppData\Local\Temp\pip-record-na3l4vzf\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\jprmj\anaconda3\Include\box2d' Check the logs for full command output.
#   Using cached Box2D-2.3.2.tar.gz (427 kB)
# Requirement already satisfied: pygame in c:\users\jprmj\anaconda3\lib\site-packages (2.1.0)
# Building wheels for collected packages: box2d
#   Building wheel for box2d (setup.py): started
#   Building wheel for box2d (setup.py): finished with status 'error'
#   Running setup.py clean for box2d
# Failed to build box2d
# Installing collected packages: box2d
#     Running setup.py install for box2d: started
#     Running setup.py install for box2d: finished with status 'error'
# Collecting box2d
#   Using cached Box2D-2.3.2.tar.gz (427 kB)
# Collecting box2d-kengz
#   Downloading Box2D-kengz-2.3.3.tar.gz (425 kB)
# Building wheels for collected packages: box2d, box2d-kengz
#   Building wheel for box2d (setup.py): started
#   Building wheel for box2d (setup.py): finished with status 'error'
#   Running setup.py clean for box2d
#   Building wheel for box2d-kengz (setup.py): started
#   Building wheel for box2d-kengz (setup.py): finished with status 'error'
#   Running setup.py clean for box2d-kengz
# Failed to build box2d box2d-kengz
# Installing collected packages: box2d-kengz, box2d
#     Running setup.py install for box2d-kengz: started
#     Running setup.py install for box2d-kengz: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\jprmj\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-th9t7hc0\\box2d_aaa9a7c217aa4fbca593ffd826620dd3\\setup.py'"'"'; __file__='"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-th9t7hc0\\box2d_aaa9a7c217aa4fbca593ffd826620dd3\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\jprmj\AppData\Local\Temp\pip-wheel-ep58dlp0'
#        cwd: C:\Users\jprmj\AppData\Local\Temp\pip-install-th9t7hc0\box2d_aaa9a7c217aa4fbca593ffd826620dd3\
#   Complete output (28 lines):
#   Using setuptools (version 58.0.4).
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\Box2D
#   copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.9\Box2D
#   copying library\Box2D\__init__.py -> build\lib.win-amd64-3.9\Box2D
#   creating build\lib.win-amd64-3.9\Box2D\b2
#   copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.9\Box2D\b2
#   running build_ext
#   building 'Box2D._Box2D' extension
#   swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#   swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#   Box2D\Common\b2Math.h(67) : Warning 302: Identifier 'b2Vec2' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#   Box2D\Common\b2Math.h(158) : Warning 302: Identifier 'b2Vec3' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#   Box2D\Common\b2Math.h(197) : Warning 302: Identifier 'b2Mat22' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#   Box2D\Common\b2Math.h(271) : Warning 302: Identifier 'b2Mat33' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#   Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#   Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#   Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#   Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for box2d
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\jprmj\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-th9t7hc0\\box2d-kengz_3728ac90a8cf455a9774e0ff4b48d0c1\\setup.py'"'"'; __file__='"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-th9t7hc0\\box2d-kengz_3728ac90a8cf455a9774e0ff4b48d0c1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\jprmj\AppData\Local\Temp\pip-wheel-p9vnc7_z'
#        cwd: C:\Users\jprmj\AppData\Local\Temp\pip-install-th9t7hc0\box2d-kengz_3728ac90a8cf455a9774e0ff4b48d0c1\
#   Complete output (28 lines):
#   Using setuptools (version 58.0.4).
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\Box2D
#   copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.9\Box2D
#   copying library\Box2D\__init__.py -> build\lib.win-amd64-3.9\Box2D
#   creating build\lib.win-amd64-3.9\Box2D\b2
#   copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.9\Box2D\b2
#   running build_ext
#   building 'Box2D._Box2D' extension
#   swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#   swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#   Box2D\Common\b2Math.h(67) : Warning 302: Identifier 'b2Vec2' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#   Box2D\Common\b2Math.h(158) : Warning 302: Identifier 'b2Vec3' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#   Box2D\Common\b2Math.h(197) : Warning 302: Identifier 'b2Mat22' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#   Box2D\Common\b2Math.h(271) : Warning 302: Identifier 'b2Mat33' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#   Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#   Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#   Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#   Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for box2d-kengz
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\jprmj\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-th9t7hc0\\box2d-kengz_3728ac90a8cf455a9774e0ff4b48d0c1\\setup.py'"'"'; __file__='"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-th9t7hc0\\box2d-kengz_3728ac90a8cf455a9774e0ff4b48d0c1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\jprmj\AppData\Local\Temp\pip-record-0i2l6tf0\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\jprmj\anaconda3\Include\box2d-kengz'
#          cwd: C:\Users\jprmj\AppData\Local\Temp\pip-install-th9t7hc0\box2d-kengz_3728ac90a8cf455a9774e0ff4b48d0c1\
#     Complete output (28 lines):
#     Using setuptools (version 58.0.4).
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\Box2D
#     copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.9\Box2D
#     copying library\Box2D\__init__.py -> build\lib.win-amd64-3.9\Box2D
#     creating build\lib.win-amd64-3.9\Box2D\b2
#     copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.9\Box2D\b2
#     running build_ext
#     building 'Box2D._Box2D' extension
#     swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#     swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#     Box2D\Common\b2Math.h(67) : Warning 302: Identifier 'b2Vec2' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#     Box2D\Common\b2Math.h(158) : Warning 302: Identifier 'b2Vec3' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#     Box2D\Common\b2Math.h(197) : Warning 302: Identifier 'b2Mat22' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#     Box2D\Common\b2Math.h(271) : Warning 302: Identifier 'b2Mat33' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#     Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#     Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#     Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#     Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\jprmj\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-th9t7hc0\\box2d-kengz_3728ac90a8cf455a9774e0ff4b48d0c1\\setup.py'"'"'; __file__='"'"'C:\\Users\\jprmj\\AppData\\Local\\Temp\\pip-install-th9t7hc0\\box2d-kengz_3728ac90a8cf455a9774e0ff4b48d0c1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\jprmj\AppData\Local\Temp\pip-record-0i2l6tf0\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\jprmj\anaconda3\Include\box2d-kengz' Check the logs for full command output.

# %%
import gym
from gym.envs import box2d 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
environment_name = "CarRacing-v0"
env = gym.make(environment_name)

# %%
log_path = os.path.join('Training', 'Logs')
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
model.learn(total_timesteps=280000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Track generation: 1081..1355 -> 274-tiles track
# Logging to Training\Logs\PPO_5
# Track generation: 1112..1394 -> 282-tiles track
# Track generation: 1202..1513 -> 311-tiles track
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -51.3    |
# | time/              |          |
# |    fps             | 118      |
# |    iterations      | 1        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Track generation: 1191..1492 -> 301-tiles track
# Track generation: 1210..1517 -> 307-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.2       |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 2           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008413268 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.00905     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.31        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00882    |
# |    std                  | 0.992       |
# |    value_loss           | 0.701       |
# -----------------------------------------
# Track generation: 1195..1498 -> 303-tiles track
# Track generation: 1108..1389 -> 281-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.3       |
# | time/                   |             |
# |    fps                  | 51          |
# |    iterations           | 3           |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007892856 |
# |    clip_fraction        | 0.0741      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.14        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00686    |
# |    std                  | 0.983       |
# |    value_loss           | 0.635       |
# -----------------------------------------
# Track generation: 1052..1321 -> 269-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1328..1664 -> 336-tiles track
# Track generation: 1147..1438 -> 291-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.1       |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 4           |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013636204 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.228       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.116       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.977       |
# |    value_loss           | 0.494       |
# -----------------------------------------
# Track generation: 1363..1714 -> 351-tiles track
# Track generation: 1068..1339 -> 271-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.6       |
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 5           |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.017236762 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0591      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0193     |
# |    std                  | 0.966       |
# |    value_loss           | 0.325       |
# -----------------------------------------
# Track generation: 1226..1536 -> 310-tiles track
# Track generation: 1223..1533 -> 310-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -49.9        |
# | time/                   |              |
# |    fps                  | 43           |
# |    iterations           | 6            |
# |    time_elapsed         | 279          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0154466685 |
# |    clip_fraction        | 0.153        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.14        |
# |    explained_variance   | 0.211        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.069        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0206      |
# |    std                  | 0.958        |
# |    value_loss           | 0.366        |
# ------------------------------------------
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 1090..1372 -> 282-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.6       |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 7           |
# |    time_elapsed         | 331         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.024436085 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.11       |
# |    explained_variance   | 0.494       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0449      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0245     |
# |    std                  | 0.947       |
# |    value_loss           | 0.264       |
# -----------------------------------------
# Track generation: 1198..1501 -> 303-tiles track
# Track generation: 941..1188 -> 247-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.9       |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 8           |
# |    time_elapsed         | 384         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.019607931 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.571       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0349      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0211     |
# |    std                  | 0.946       |
# |    value_loss           | 0.272       |
# -----------------------------------------
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1352..1705 -> 353-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1266..1594 -> 328-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -53.8      |
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 9          |
# |    time_elapsed         | 435        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01835237 |
# |    clip_fraction        | 0.172      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.08      |
# |    explained_variance   | 0.737      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0217    |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0193    |
# |    std                  | 0.939      |
# |    value_loss           | 0.243      |
# ----------------------------------------
# Track generation: 1316..1649 -> 333-tiles track
# Track generation: 997..1253 -> 256-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1044..1317 -> 273-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -55.1       |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 10          |
# |    time_elapsed         | 488         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.018500673 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00224     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0207     |
# |    std                  | 0.926       |
# |    value_loss           | 0.21        |
# -----------------------------------------
# Track generation: 1186..1495 -> 309-tiles track
# Track generation: 1107..1388 -> 281-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -56.4       |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 11          |
# |    time_elapsed         | 544         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.021590436 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0295      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0216     |
# |    std                  | 0.911       |
# |    value_loss           | 0.192       |
# -----------------------------------------
# Track generation: 1082..1362 -> 280-tiles track
# Track generation: 1087..1371 -> 284-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -57.2      |
# | time/                   |            |
# |    fps                  | 41         |
# |    iterations           | 12         |
# |    time_elapsed         | 596        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01499548 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.97      |
# |    explained_variance   | 0.876      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00883    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.017     |
# |    std                  | 0.906      |
# |    value_loss           | 0.144      |
# ----------------------------------------
# Track generation: 1196..1499 -> 303-tiles track
# Track generation: 1175..1473 -> 298-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -58.4       |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 13          |
# |    time_elapsed         | 648         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014914088 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.756       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0101      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.901       |
# |    value_loss           | 0.165       |
# -----------------------------------------
# Track generation: 1095..1373 -> 278-tiles track
# Track generation: 1100..1379 -> 279-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -58.8       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 14          |
# |    time_elapsed         | 699         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.019198548 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0397     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0242     |
# |    std                  | 0.889       |
# |    value_loss           | 0.0934      |
# -----------------------------------------
# Track generation: 1022..1282 -> 260-tiles track
# Track generation: 1077..1350 -> 273-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -59.6      |
# | time/                   |            |
# |    fps                  | 40         |
# |    iterations           | 15         |
# |    time_elapsed         | 753        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01944677 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.87      |
# |    explained_variance   | 0.914      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00995    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0228    |
# |    std                  | 0.87       |
# |    value_loss           | 0.14       |
# ----------------------------------------
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -60.4       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 16          |
# |    time_elapsed         | 806         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.018552238 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0267     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0233     |
# |    std                  | 0.859       |
# |    value_loss           | 0.0796      |
# -----------------------------------------
# Track generation: 1209..1515 -> 306-tiles track
# Track generation: 1102..1387 -> 285-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -60         |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 17          |
# |    time_elapsed         | 858         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.015403619 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0142     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0203     |
# |    std                  | 0.847       |
# |    value_loss           | 0.0631      |
# -----------------------------------------
# Track generation: 1102..1382 -> 280-tiles track
# Track generation: 1128..1414 -> 286-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -60.4       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 18          |
# |    time_elapsed         | 911         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.029707666 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0311     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0372     |
# |    std                  | 0.832       |
# |    value_loss           | 0.218       |
# -----------------------------------------
# Track generation: 1118..1402 -> 284-tiles track
# Track generation: 1243..1558 -> 315-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -60.6      |
# | time/                   |            |
# |    fps                  | 40         |
# |    iterations           | 19         |
# |    time_elapsed         | 962        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.03551223 |
# |    clip_fraction        | 0.271      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.69      |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0139     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0291    |
# |    std                  | 0.822      |
# |    value_loss           | 0.104      |
# ----------------------------------------
# Track generation: 1109..1390 -> 281-tiles track
# Track generation: 940..1179 -> 239-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -61.3       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 20          |
# |    time_elapsed         | 1013        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.033132292 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0169     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.029      |
# |    std                  | 0.81        |
# |    value_loss           | 0.0525      |
# -----------------------------------------
# Track generation: 1118..1405 -> 287-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1067..1344 -> 277-tiles track
# Track generation: 1290..1617 -> 327-tiles track
# Track generation: 1142..1438 -> 296-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -62.3       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 21          |
# |    time_elapsed         | 1065        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.021784991 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0192     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.809       |
# |    value_loss           | 0.0611      |
# -----------------------------------------
# Track generation: 1235..1548 -> 313-tiles track
# Track generation: 1176..1474 -> 298-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -63.1       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 22          |
# |    time_elapsed         | 1117        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.031899206 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0309     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0279     |
# |    std                  | 0.798       |
# |    value_loss           | 0.0463      |
# -----------------------------------------
# Track generation: 1139..1428 -> 289-tiles track
# Track generation: 1143..1433 -> 290-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -63.6       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 23          |
# |    time_elapsed         | 1169        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.022506448 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0337     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0264     |
# |    std                  | 0.796       |
# |    value_loss           | 0.0406      |
# -----------------------------------------
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 951..1197 -> 246-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -64.1       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 24          |
# |    time_elapsed         | 1226        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.029776104 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0503     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0284     |
# |    std                  | 0.789       |
# |    value_loss           | 0.0373      |
# -----------------------------------------
# Track generation: 974..1221 -> 247-tiles track
# Track generation: 984..1234 -> 250-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -64.4       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 25          |
# |    time_elapsed         | 1279        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.030137155 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0214     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0278     |
# |    std                  | 0.782       |
# |    value_loss           | 0.0282      |
# -----------------------------------------
# Track generation: 1107..1388 -> 281-tiles track
# Track generation: 986..1242 -> 256-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -64.6       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 26          |
# |    time_elapsed         | 1330        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.030738024 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.52       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0139     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0235     |
# |    std                  | 0.781       |
# |    value_loss           | 0.066       |
# -----------------------------------------
# Track generation: 1191..1503 -> 312-tiles track
# Track generation: 1072..1347 -> 275-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1159..1453 -> 294-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -64.9       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 27          |
# |    time_elapsed         | 1385        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.030273024 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0482     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.03       |
# |    std                  | 0.771       |
# |    value_loss           | 0.0437      |
# -----------------------------------------
# Track generation: 1112..1394 -> 282-tiles track
# Track generation: 1040..1309 -> 269-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -65.1      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 28         |
# |    time_elapsed         | 1438       |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.06201616 |
# |    clip_fraction        | 0.28       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.48      |
# |    explained_variance   | 0.978      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0592    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0317    |
# |    std                  | 0.769      |
# |    value_loss           | 0.0603     |
# ----------------------------------------
# Track generation: 1124..1409 -> 285-tiles track
# Track generation: 1069..1340 -> 271-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -64.9       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 29          |
# |    time_elapsed         | 1489        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.037363134 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.44       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0498     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0361     |
# |    std                  | 0.755       |
# |    value_loss           | 0.0622      |
# -----------------------------------------
# Track generation: 1251..1570 -> 319-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -64.4      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 30         |
# |    time_elapsed         | 1541       |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.04579766 |
# |    clip_fraction        | 0.361      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.4       |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0428    |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0353    |
# |    std                  | 0.746      |
# |    value_loss           | 0.0912     |
# ----------------------------------------
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1205..1510 -> 305-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -64         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 31          |
# |    time_elapsed         | 1593        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.050449055 |
# |    clip_fraction        | 0.391       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.37       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0475     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0458     |
# |    std                  | 0.742       |
# |    value_loss           | 0.134       |
# -----------------------------------------
# Track generation: 1190..1492 -> 302-tiles track
# Track generation: 1196..1499 -> 303-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -63.5       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 32          |
# |    time_elapsed         | 1645        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.064589754 |
# |    clip_fraction        | 0.389       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.35       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00804     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0507     |
# |    std                  | 0.736       |
# |    value_loss           | 0.163       |
# -----------------------------------------
# Track generation: 1087..1363 -> 276-tiles track
# Track generation: 1190..1492 -> 302-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -62.7       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 33          |
# |    time_elapsed         | 1698        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.058243755 |
# |    clip_fraction        | 0.389       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.31       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0636     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0483     |
# |    std                  | 0.724       |
# |    value_loss           | 0.152       |
# -----------------------------------------
# Track generation: 1267..1588 -> 321-tiles track
# Track generation: 1123..1408 -> 285-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -62.2      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 34         |
# |    time_elapsed         | 1751       |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.05307203 |
# |    clip_fraction        | 0.368      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.27      |
# |    explained_variance   | 0.872      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0215    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0431    |
# |    std                  | 0.715      |
# |    value_loss           | 0.227      |
# ----------------------------------------
# Track generation: 1080..1354 -> 274-tiles track
# Track generation: 1188..1489 -> 301-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -60.8       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 35          |
# |    time_elapsed         | 1802        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.061261803 |
# |    clip_fraction        | 0.399       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0529      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0496     |
# |    std                  | 0.702       |
# |    value_loss           | 0.219       |
# -----------------------------------------
# Track generation: 1200..1504 -> 304-tiles track
# Track generation: 1104..1384 -> 280-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -60.4       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 36          |
# |    time_elapsed         | 1854        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.068389006 |
# |    clip_fraction        | 0.414       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0933      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.046      |
# |    std                  | 0.697       |
# |    value_loss           | 0.481       |
# -----------------------------------------
# Track generation: 1155..1448 -> 293-tiles track
# Track generation: 1081..1358 -> 277-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1140..1429 -> 289-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -59.1       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 37          |
# |    time_elapsed         | 1906        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.076492086 |
# |    clip_fraction        | 0.405       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0561     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0562     |
# |    std                  | 0.686       |
# |    value_loss           | 0.182       |
# -----------------------------------------
# Track generation: 1111..1393 -> 282-tiles track
# Track generation: 1276..1599 -> 323-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -57.3      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 38         |
# |    time_elapsed         | 1960       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.08128206 |
# |    clip_fraction        | 0.43       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.1       |
# |    explained_variance   | 0.789      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0445    |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0441    |
# |    std                  | 0.675      |
# |    value_loss           | 0.505      |
# ----------------------------------------
# Track generation: 1220..1530 -> 310-tiles track
# Track generation: 1300..1629 -> 329-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -54.6      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 39         |
# |    time_elapsed         | 2015       |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.08821465 |
# |    clip_fraction        | 0.462      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.06      |
# |    explained_variance   | 0.847      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0373     |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0408    |
# |    std                  | 0.668      |
# |    value_loss           | 0.513      |
# ----------------------------------------
# Track generation: 1139..1434 -> 295-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1239..1553 -> 314-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -53.9      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 40         |
# |    time_elapsed         | 2068       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.08069104 |
# |    clip_fraction        | 0.432      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.03      |
# |    explained_variance   | 0.893      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0341    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.044     |
# |    std                  | 0.662      |
# |    value_loss           | 0.58       |
# ----------------------------------------
# Track generation: 1007..1263 -> 256-tiles track
# Track generation: 1301..1637 -> 336-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -51.4      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 41         |
# |    time_elapsed         | 2121       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.07875354 |
# |    clip_fraction        | 0.397      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3         |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0229     |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0453    |
# |    std                  | 0.655      |
# |    value_loss           | 0.206      |
# ----------------------------------------
# Track generation: 1261..1590 -> 329-tiles track
# Track generation: 1048..1314 -> 266-tiles track
# Track generation: 1215..1523 -> 308-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -45.6      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 42         |
# |    time_elapsed         | 2175       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.06842375 |
# |    clip_fraction        | 0.412      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.97      |
# |    explained_variance   | 0.929      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00837    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0395    |
# |    std                  | 0.649      |
# |    value_loss           | 0.769      |
# ----------------------------------------
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1047..1322 -> 275-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -44.6       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 43          |
# |    time_elapsed         | 2228        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.077791125 |
# |    clip_fraction        | 0.466       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.105       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0343     |
# |    std                  | 0.643       |
# |    value_loss           | 1.11        |
# -----------------------------------------
# Track generation: 1019..1288 -> 269-tiles track
# Track generation: 1072..1351 -> 279-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -41.4      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 44         |
# |    time_elapsed         | 2281       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.07755848 |
# |    clip_fraction        | 0.423      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.92      |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0237    |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0367    |
# |    std                  | 0.64       |
# |    value_loss           | 0.376      |
# ----------------------------------------
# Track generation: 1113..1395 -> 282-tiles track
# Track generation: 1071..1343 -> 272-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -36.6       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 45          |
# |    time_elapsed         | 2332        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.074132115 |
# |    clip_fraction        | 0.414       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.91       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0668      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0209     |
# |    std                  | 0.637       |
# |    value_loss           | 0.897       |
# -----------------------------------------
# Track generation: 1073..1345 -> 272-tiles track
# Track generation: 1079..1356 -> 277-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1009..1312 -> 303-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1268..1589 -> 321-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -36        |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 46         |
# |    time_elapsed         | 2384       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.07204198 |
# |    clip_fraction        | 0.439      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.88      |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.109      |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0201    |
# |    std                  | 0.632      |
# |    value_loss           | 1.46       |
# ----------------------------------------
# Track generation: 1123..1408 -> 285-tiles track
# Track generation: 1123..1408 -> 285-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -32.5      |
# | time/                   |            |
# |    fps                  | 39         |
# ...
# |    approx_kl            | 0.12591614 |
# |    clip_fraction        | 0.561      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.7       |
# |    explained_variance   | 0.766      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.984      |
# |    n_updates            | 1210       |
# |    policy_gradient_loss | 0.00752    |
# |    std                  | 0.598      |
# |    value_loss           | 7.99       |
# ----------------------------------------
# Track generation: 1224..1534 -> 310-tiles track
# Track generation: 1090..1366 -> 276-tiles track
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 959       |
# |    ep_rew_mean          | 285       |
# | time/                   |           |
# |    fps                  | 39        |
# |    iterations           | 123       |
# |    time_elapsed         | 6376      |
# |    total_timesteps      | 251904    |
# | train/                  |           |
# |    approx_kl            | 0.1507115 |
# |    clip_fraction        | 0.554     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.68     |
# |    explained_variance   | 0.903     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.827     |
# |    n_updates            | 1220      |
# |    policy_gradient_loss | 0.0208    |
# |    std                  | 0.596     |
# |    value_loss           | 10.5      |
# ---------------------------------------
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1162..1457 -> 295-tiles track
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 959       |
# |    ep_rew_mean          | 289       |
# | time/                   |           |
# |    fps                  | 39        |
# |    iterations           | 124       |
# |    time_elapsed         | 6427      |
# |    total_timesteps      | 253952    |
# | train/                  |           |
# |    approx_kl            | 0.1052006 |
# |    clip_fraction        | 0.562     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.68     |
# |    explained_variance   | 0.884     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.681     |
# |    n_updates            | 1230      |
# |    policy_gradient_loss | 0.0341    |
# |    std                  | 0.598     |
# |    value_loss           | 5.6       |
# ---------------------------------------
# Track generation: 1061..1340 -> 279-tiles track
# Track generation: 1264..1584 -> 320-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 959        |
# |    ep_rew_mean          | 298        |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 125        |
# |    time_elapsed         | 6478       |
# |    total_timesteps      | 256000     |
# | train/                  |            |
# |    approx_kl            | 0.11007735 |
# |    clip_fraction        | 0.527      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.68      |
# |    explained_variance   | 0.922      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.827      |
# |    n_updates            | 1240       |
# |    policy_gradient_loss | 0.0083     |
# |    std                  | 0.595      |
# |    value_loss           | 4.19       |
# ----------------------------------------
# Track generation: 1028..1289 -> 261-tiles track
# Track generation: 1044..1314 -> 270-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 959         |
# |    ep_rew_mean          | 305         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 126         |
# |    time_elapsed         | 6529        |
# |    total_timesteps      | 258048      |
# | train/                  |             |
# |    approx_kl            | 0.120016485 |
# |    clip_fraction        | 0.527       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.492       |
# |    n_updates            | 1250        |
# |    policy_gradient_loss | 0.00136     |
# |    std                  | 0.596       |
# |    value_loss           | 5.69        |
# -----------------------------------------
# Track generation: 1031..1292 -> 261-tiles track
# Track generation: 1119..1406 -> 287-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1147..1438 -> 291-tiles track
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 959       |
# |    ep_rew_mean          | 311       |
# | time/                   |           |
# |    fps                  | 39        |
# |    iterations           | 127       |
# |    time_elapsed         | 6580      |
# |    total_timesteps      | 260096    |
# | train/                  |           |
# |    approx_kl            | 0.1232861 |
# |    clip_fraction        | 0.529     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.67     |
# |    explained_variance   | 0.917     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.13      |
# |    n_updates            | 1260      |
# |    policy_gradient_loss | 0.0199    |
# |    std                  | 0.598     |
# |    value_loss           | 9.66      |
# ---------------------------------------
# Track generation: 1044..1308 -> 264-tiles track
# Track generation: 1139..1428 -> 289-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 959        |
# |    ep_rew_mean          | 322        |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 128        |
# |    time_elapsed         | 6632       |
# |    total_timesteps      | 262144     |
# | train/                  |            |
# |    approx_kl            | 0.10176897 |
# |    clip_fraction        | 0.541      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.68      |
# |    explained_variance   | 0.885      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.955      |
# |    n_updates            | 1270       |
# |    policy_gradient_loss | 0.0185     |
# |    std                  | 0.599      |
# |    value_loss           | 6.59       |
# ----------------------------------------
# Track generation: 1119..1411 -> 292-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 959         |
# |    ep_rew_mean          | 324         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 129         |
# |    time_elapsed         | 6683        |
# |    total_timesteps      | 264192      |
# | train/                  |             |
# |    approx_kl            | 0.118015215 |
# |    clip_fraction        | 0.53        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.75        |
# |    n_updates            | 1280        |
# |    policy_gradient_loss | 0.00227     |
# |    std                  | 0.599       |
# |    value_loss           | 4.53        |
# -----------------------------------------
# Track generation: 1292..1619 -> 327-tiles track
# Track generation: 1222..1532 -> 310-tiles track
# Track generation: 1168..1464 -> 296-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 959        |
# |    ep_rew_mean          | 334        |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 130        |
# |    time_elapsed         | 6734       |
# |    total_timesteps      | 266240     |
# | train/                  |            |
# |    approx_kl            | 0.10519013 |
# |    clip_fraction        | 0.462      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.69      |
# |    explained_variance   | 0.984      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.323      |
# |    n_updates            | 1290       |
# |    policy_gradient_loss | 0.0158     |
# |    std                  | 0.598      |
# |    value_loss           | 2.47       |
# ----------------------------------------
# Track generation: 1197..1500 -> 303-tiles track
# Track generation: 1127..1413 -> 286-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 959        |
# |    ep_rew_mean          | 340        |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 131        |
# |    time_elapsed         | 6788       |
# |    total_timesteps      | 268288     |
# | train/                  |            |
# |    approx_kl            | 0.07690749 |
# |    clip_fraction        | 0.455      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.68      |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.01       |
# |    n_updates            | 1300       |
# |    policy_gradient_loss | 0.00531    |
# |    std                  | 0.599      |
# |    value_loss           | 6.08       |
# ----------------------------------------
# Track generation: 1046..1315 -> 269-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1202..1506 -> 304-tiles track
# Track generation: 1125..1411 -> 286-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 959        |
# |    ep_rew_mean          | 348        |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 132        |
# |    time_elapsed         | 6840       |
# |    total_timesteps      | 270336     |
# | train/                  |            |
# |    approx_kl            | 0.10690763 |
# |    clip_fraction        | 0.465      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.7       |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.533      |
# |    n_updates            | 1310       |
# |    policy_gradient_loss | -0.00143   |
# |    std                  | 0.606      |
# |    value_loss           | 4.28       |
# ----------------------------------------
# Track generation: 1012..1269 -> 257-tiles track
# Track generation: 1200..1504 -> 304-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 959        |
# |    ep_rew_mean          | 358        |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 133        |
# |    time_elapsed         | 6890       |
# |    total_timesteps      | 272384     |
# | train/                  |            |
# |    approx_kl            | 0.10578407 |
# |    clip_fraction        | 0.48       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.69      |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.617      |
# |    n_updates            | 1320       |
# |    policy_gradient_loss | 0.000316   |
# |    std                  | 0.598      |
# |    value_loss           | 3.85       |
# ----------------------------------------
# Track generation: 1309..1641 -> 332-tiles track
# Track generation: 1151..1443 -> 292-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 959        |
# |    ep_rew_mean          | 363        |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 134        |
# |    time_elapsed         | 6941       |
# |    total_timesteps      | 274432     |
# | train/                  |            |
# |    approx_kl            | 0.08030416 |
# |    clip_fraction        | 0.491      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.67      |
# |    explained_variance   | 0.881      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.724      |
# |    n_updates            | 1330       |
# |    policy_gradient_loss | 0.0111     |
# |    std                  | 0.598      |
# |    value_loss           | 8.82       |
# ----------------------------------------
# Track generation: 1101..1383 -> 282-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1024..1282 -> 258-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1230..1542 -> 312-tiles track
# Track generation: 960..1204 -> 244-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 965        |
# |    ep_rew_mean          | 369        |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 135        |
# |    time_elapsed         | 6993       |
# |    total_timesteps      | 276480     |
# | train/                  |            |
# |    approx_kl            | 0.14961389 |
# |    clip_fraction        | 0.471      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.67      |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.697      |
# |    n_updates            | 1340       |
# |    policy_gradient_loss | 0.0172     |
# |    std                  | 0.6        |
# |    value_loss           | 5.73       |
# ----------------------------------------
# Track generation: 1332..1669 -> 337-tiles track
# Track generation: 945..1193 -> 248-tiles track
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 965       |
# |    ep_rew_mean          | 373       |
# | time/                   |           |
# |    fps                  | 39        |
# |    iterations           | 136       |
# |    time_elapsed         | 7045      |
# |    total_timesteps      | 278528    |
# | train/                  |           |
# |    approx_kl            | 0.1186938 |
# |    clip_fraction        | 0.503     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.68     |
# |    explained_variance   | 0.973     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.941     |
# |    n_updates            | 1350      |
# |    policy_gradient_loss | 0.00885   |
# |    std                  | 0.597     |
# |    value_loss           | 5.13      |
# ---------------------------------------
# Track generation: 1053..1320 -> 267-tiles track
# Track generation: 1071..1343 -> 272-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 965        |
# |    ep_rew_mean          | 379        |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 137        |
# |    time_elapsed         | 7095       |
# |    total_timesteps      | 280576     |
# | train/                  |            |
# |    approx_kl            | 0.17510213 |
# |    clip_fraction        | 0.464      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.67      |
# |    explained_variance   | 0.969      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.447      |
# |    n_updates            | 1360       |
# |    policy_gradient_loss | 0.000873   |
# |    std                  | 0.6        |
# |    value_loss           | 5.22       |
# ----------------------------------------

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# c:\Users\jprmj\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Track generation: 1263..1583 -> 320-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1121..1405 -> 284-tiles track
# Track generation: 1122..1413 -> 291-tiles track
# Track generation: 1048..1314 -> 266-tiles track
# Track generation: 1238..1552 -> 314-tiles track
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 1138..1426 -> 288-tiles track
# Track generation: 1080..1362 -> 282-tiles track
# Track generation: 1239..1553 -> 314-tiles track
# Track generation: 1187..1488 -> 301-tiles track
# (172.31544390916824, 78.5506132088392)

# %%
# Out:
# O Kernel falhou ao executar o código na célula atual ou em uma célula anterior. Examine o código nas células para identificar uma possível causa da falha. Clique <a href="https://aka.ms/vscodeJupyterKernelCrash">aqui</a> para obter mais informações. Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.
